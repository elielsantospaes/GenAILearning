# %%
# %pip install mlflow==2.10.1 lxml==4.9.3 langchain==0.1.5 databricks-sdk==0.18.0 databricks-vectorsearch==0.22 cloudpickle==2.2.1 pydantic==2.5.2 sentence-transformers
# %pip install pip mlflow[databricks]==2.10.1

dbutils.library.restartPython()

# %%
from databricks.sdk import WorkspaceClient
from databricks.vector_search.client import VectorSearchClient

vsc = VectorSearchClient(disable_notice = True)

# %%
vsc_endpoint = "eliel_paes_estudies"
catalogo = "analytics"
db_name = "bronze"
source_table = "pdf_raw_text"

# %%
wait_for_vs_endoint_to_be_ready(vsc, vsc_endpoint)
